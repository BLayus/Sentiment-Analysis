# %% [markdown]
# <a href="https://colab.research.google.com/github/BLayus/Sentiment-Analysis/blob/main/Webscrapping_API_Twitter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install tweepy

import tweepy as tw

# %%
api_key = 'bZD6d3QYbsgqwkteNGoqfbQPp'

api_key_secret = 'r6nLWRrSH9HDizbB39n2DqLbLAcZWCqDsSQtpSTHO2azNIyjae'

accesss_token = '2560618594-xNBFHggcdFA3S2ntNY1hYqudT37W0AdZaBa2jZ9'

access_token_secret ='ExSkQ9KcXxsLhGBHmmYvRDUX0IA9q6grdMb294WCAbscI'

# %%
auth = tw.OAuthHandler(api_key, api_key_secret)

auth.set_access_token(accesss_token, access_token_secret)

# %%
api = tw.API(auth)

# %%
tweets = api.user_timeline(screen_name='tadeuschmidt', include_rts=False)

# %%
for tweet in tweets:
  print(tweet.text)
# Out:
# A entrada dos últimos 3 moradores foi EMOCIONANTE!!! Que demais!!! Casa completa!!! #bbb22
# COMEÇOU! Que felicidade! Que honra! E o melhor está por vir… Obrigado pelo carinho!
# Chegou o BIG DAAAAAY!!!
# Aguardando os comentários sobre os nomes… 😊
# #BBB22 #BIGDAY
# Voltei…
# #NovaFotoDePerfil https://t.co/KD3tYqEQ0x
# Esta é a maior lembrança que eu tenho daquele dia: Oscar comemorando como um louco - de um jeito… https://t.co/3a9Za6Pphz
# @gustavoemota @showdavida Discordo...
# @pceneviva @showdavida Falamos, sim! É que o Botafogo tá numa posição intermediária, por isso, aparece menos. Deixa… https://t.co/IqYE9DU1sk
# @ClaudiaLeitte 😱tô procurando aqui um emoji de queixo caído, babando com esse Tweet, não encontrei! @ClaudiaLeitte,… https://t.co/sM8hGNKA8R
# @Mariacscastilho @showdavida Vamos responder no @showdavida de hoje!!!
# Pessoal, para tudo!
# Olha quem tá no @showdavida hoje! @andyserkis é O CARA quando se trata de… https://t.co/5hMji8xevW
# Que golaço do @rever_5 !!! 😱
# ...

# %%
tweets = api.user_timeline(screen_name='tadeuschmidt', include_rts=False, tweet_mode='extended')

# %%
for tweet in tweets:
  print(tweet.user.screen_name)
  print(tweet.full_text, '\n')
# Out:
# tadeuschmidt
# A entrada dos últimos 3 moradores foi EMOCIONANTE!!! Que demais!!! Casa completa!!! #bbb22
#
# tadeuschmidt
# COMEÇOU! Que felicidade! Que honra! E o melhor está por vir… Obrigado pelo carinho!
#
# tadeuschmidt
# Chegou o BIG DAAAAAY!!!
# Aguardando os comentários sobre os nomes… 😊
# #BBB22 #BIGDAY
#
# tadeuschmidt
# Voltei…
#
# tadeuschmidt
# #NovaFotoDePerfil https://t.co/KD3tYqEQ0x
#
# tadeuschmidt
# Esta é a maior lembrança que eu tenho daquele dia: Oscar comemorando como um louco - de um jeito… https://t.co/3a9Za6Pphz
#
# tadeuschmidt
# @gustavoemota @showdavida Discordo...
#
# tadeuschmidt
# @pceneviva @showdavida Falamos, sim! É que o Botafogo tá numa posição intermediária, por isso, aparece menos. Deixa ele encostar no Corinthians pra você ver...
#
# tadeuschmidt
# @ClaudiaLeitte 😱tô procurando aqui um emoji de queixo caído, babando com esse Tweet, não encontrei! @ClaudiaLeitte, linda, o fã aqui sou eu. Um beijão.
#
# tadeuschmidt
# ...

# %%
tweets = api.search(q='rio de janeiro', tweet_mode='extended')

# %%
for tweet in tweets:
  print(tweet.user.screen_name)
  print(tweet.full_text, '\n')
# Out:
# enzomotalima
# RT @bchartsnet: Morre aos 91 anos a icônica cantora Elza Soares. A artista estava no Rio de Janeiro e faleceu de causas naturais segundo co…
#
# pfvclarinha
# RT @bchartsnet: Morre aos 91 anos a icônica cantora Elza Soares. A artista estava no Rio de Janeiro e faleceu de causas naturais segundo co…
#
# BambiJewerlry
# Best Luxury Hotels PORTOBAY RIO DE JANEIRO (BRAZIL) https://t.co/39bweVEw4Q via @YouTube
# #luxuryhomes #luxurylifestyle
#
# bsbsquadbr
# Hoje é feriado no Rio de Janeiro! @nickcarter está no clima! 💚🌎 #backstreetboys #bsbfans #bsbsquadbr #ktbspa #nickcarter https://t.co/KXL4VZ2y36
#
# Lari_NC
# RT @TomasRosolino: Instalados na Rua Maranhão, em Higienopolis, os dois fizeram questão de aproveitar a mudança de ares em relação ao Rio d…
#
# operamundi
# Considerada a 'cantora brasileira do milênio', artista faleceu de causas naturais; Elza lançou 34 discos com misturas de diversos gêneros musicais https://t.co/nYJiWPDcqb
#
# marlenesophia21
# ...

# %%
tweets = api.search(q='#bbb', tweet_mode='extended')

# %%
for tweet in tweets:
  print(tweet.user.screen_name)
  print(tweet.full_text, '\n')
# Out:
# Bill_Chernowill
# Mano, não suporto mais o Rodrigo no #BBB
#
# Esse cara não descansa, é o tempo inteiro elaborando estratégia de jogo, conspirando e tal
#
# _OnlyABanshee
# RT @lexcauseyes: o fiuk saiu mas a alma ficou.
# #bbb
# #bbb22
# insuportável https://t.co/jXy4HCg4an
#
# jhopoc
# @choquei #gfvip #tzvip #rosmello #prelemi #gregorelli #euphoria #bigbrotherbrasil #bbtvi21 #spiderman #bbb #bbtvi #bbb22 #snowdrop #nowayhome #snowdropEP11  #badbuddyseriesEP10 #BadBuddySeriesEP12
#
# https://t.co/j3cTIjV6Qa
#
# Victor60704664
# @globoplay CADE O QUERIDOMETRO PARA NÓS AVALIARMOS.
# #BBB #BBB22
#
# juliafritas
# RT @askdiggory: a jade picão quando receber conselho dos outros participantes
#
# #BBB jade picona AVISA QUE É ELA linn da quebrada https://t…
#
# emilipereira_
# RT @transpreta: Qualquer semelhança é mera coincidência #BBB22 #BBB 😂🤣 https://t.co/PXfXPsehaP
#
# BrunoMo34646060
# ...

# %%
tweets = api.search(q='bbb AND coca cola', tweet_mode='extended')

# %%
for tweet in tweets:
  print(tweet.user.screen_name)
  print(tweet.full_text, '\n')
# Out:
# PalomaQueiroz20
# O Mion tá querendo ensinar como o Tadeu deve apresentar o bbb, se ele tivesse algo pra falar q fosse em off, bem sem noção da parte dele. Sem falar q ele não é essa coca cola toda, chegou ontem na emissora e já tá se achando e isso é culpa de Boninho q dá muita asa.
#
# jozgil
# eu sonhei que eu tava com jade picão e arthur aguiar pra entrar no BBB e quem tava levando a gnt era Luciano Huck e Angélica e fomos comer lá em Tupas e que a coca cola de 2l era 150 reais
#
# viminipulse
# foda do bbb é que n tem uma coca cola
#
# divinopudim
# Tem coca-cola no bbb?
#
# sweetvivipas
# RT @tuitanella: se eu ficasse três dias sem coca cola no bbb eu surtaria com todo mundo inclusive com o boninho https://t.co/inses05Nhl
#
# tuitanella
# se eu ficasse três dias sem coca cola no bbb eu surtaria com todo mundo inclusive com o boninho https://t.co/inses05Nhl
#
# edineiamacedorr
# ...

# %%
tweets_list = []

for tweet in tweets:
  tweets_list.append(tweet._json)

# %%
tweets_list
# Out:
# [{'contributors': None,
#   'coordinates': None,
#   'created_at': 'Thu Jan 20 14:15:55 +0000 2022',
#   'display_text_range': [0, 266],
#   'entities': {'hashtags': [], 'symbols': [], 'urls': [], 'user_mentions': []},
#   'favorite_count': 0,
#   'favorited': False,
#   'full_text': 'O Mion tá querendo ensinar como o Tadeu deve apresentar o bbb, se ele tivesse algo pra falar q fosse em off, bem sem noção da parte dele. Sem falar q ele não é essa coca cola toda, chegou ontem na emissora e já tá se achando e isso é culpa de Boninho q dá muita asa.',
#   'geo': None,
#   'id': 1484167811740094464,
#   'id_str': '1484167811740094464',
#   'in_reply_to_screen_name': None,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'is_quote_status': False,
#   'lang': 'pt',
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'place': None,
#   'retweet_count': 0,
# ...

# %%
import pandas as pd

# %%
df = pd.json_normalize(tweets_list)

# %%
df.head()
# Out:
#                        created_at  ...  retweeted_status.lang
# 0  Thu Jan 20 14:15:55 +0000 2022  ...                    NaN
# 1  Thu Jan 20 11:35:34 +0000 2022  ...                    NaN
# 2  Thu Jan 20 02:08:21 +0000 2022  ...                    NaN
# 3  Thu Jan 20 01:51:51 +0000 2022  ...                    NaN
# 4  Wed Jan 19 19:12:10 +0000 2022  ...                     pt
#
# [5 rows x 149 columns]

# %%
df.to_csv('tweets_COCACOLA_BBB.csv')
